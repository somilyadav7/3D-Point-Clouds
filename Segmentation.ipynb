# %%
import os
import json
import random
import numpy as np
import pandas as pd
from tqdm import tqdm
from glob import glob

import tensorflow as tf  # For tf.data
import keras
from keras import layers

import matplotlib.pyplot as plt

# %%
dataset_url = "https://git.io/JiY4i"

dataset_path = keras.utils.get_file(
    fname="shapenet.zip",
    origin=dataset_url,
    cache_subdir="datasets",
    hash_algorithm="auto",
    extract=True,
    archive_format="auto",
    cache_dir="datasets",
)
# Out:
# Downloading data from https://git.io/JiY4i
# 1078925405/1078925405 [==============================] - 6s 0us/step

# %%
with open("/tmp/.keras/datasets/PartAnnotation/metadata.json") as json_file:
    metadata = json.load(json_file)

# Iterate through the items
for key, value in metadata.items():
    print(f"{key}: {value}")
# Out:
# Airplane: {'directory': '02691156', 'lables': ['wing', 'body', 'tail', 'engine'], 'colors': ['blue', 'green', 'red', 'pink']}
# Bag: {'directory': '02773838', 'lables': ['handle', 'body'], 'colors': ['blue', 'green']}
# Cap: {'directory': '02954340', 'lables': ['panels', 'peak'], 'colors': ['blue', 'green']}
# Car: {'directory': '02958343', 'lables': ['wheel', 'hood', 'roof'], 'colors': ['blue', 'green', 'red']}
# Chair: {'directory': '03001627', 'lables': ['leg', 'arm', 'back', 'seat'], 'colors': ['blue', 'green', 'red', 'pink']}
# Earphone: {'directory': '03261776', 'lables': ['earphone', 'headband'], 'colors': ['blue', 'green']}
# Guitar: {'directory': '03467517', 'lables': ['head', 'body', 'neck'], 'colors': ['blue', 'green', 'red']}
# Knife: {'directory': '03624134', 'lables': ['handle', 'blade'], 'colors': ['blue', 'green']}
# Lamp: {'directory': '03636649', 'lables': ['canopy', 'lampshade', 'base'], 'colors': ['blue', 'green', 'red']}
# Laptop: {'directory': '03642806', 'lables': ['keyboard'], 'colors': ['blue']}
# Motorbike: {'directory': '03790512', 'lables': ['wheel', 'handle', 'gas_tank', 'light', 'seat'], 'colors': ['blue', 'green', 'red', 'pink', 'yellow']}
# Mug: {'directory': '03797390', 'lables': ['handle'], 'colors': ['blue']}
# Pistol: {'directory': '03948459', 'lables': ['trigger_and_guard', 'handle', 'barrel'], 'colors': ['blue', 'green', 'red']}
# Rocket: {'directory': '04099429', 'lables': ['nose', 'body', 'fin'], 'colors': ['blue', 'green', 'red']}
# Skateboard: {'directory': '04225987', 'lables': ['wheel', 'deck'], 'colors': ['blue', 'green']}
# Table: {'directory': '04379243', 'lables': ['leg', 'top'], 'colors': ['blue', 'green']}

# %%
points_dir = "/tmp/.keras/datasets/PartAnnotation/{}/points".format(
    metadata["Airplane"]["directory"]
)
labels_dir = "/tmp/.keras/datasets/PartAnnotation/{}/points_label".format(
    metadata["Airplane"]["directory"]
)
LABELS = metadata["Airplane"]["lables"]
COLORS = metadata["Airplane"]["colors"]

VAL_SPLIT = 0.2
NUM_SAMPLE_POINTS = 2048
BATCH_SIZE = 32

# %%
point_clouds, test_point_clouds = [], []
point_cloud_labels, all_labels = [], []

points_files = glob(os.path.join(points_dir, "*.pts"))
for point_file in tqdm(points_files):
    point_cloud = np.loadtxt(point_file)
    if point_cloud.shape[0] < NUM_SAMPLE_POINTS:
        continue

    # Get the file-id of the current point cloud for parsing its
    # labels.
    file_id = point_file.split("/")[-1].split(".")[0]
    label_data, num_labels = {}, 0
    for label in LABELS:
        label_file = os.path.join(labels_dir, label, file_id + ".seg")
        if os.path.exists(label_file):
            label_data[label] = np.loadtxt(label_file).astype("float32")
            num_labels = len(label_data[label])
    # Point clouds having labels will be our training samples.
    try:
        label_map = ["none"] * num_labels
        for label in LABELS:
            for i, data in enumerate(label_data[label]):
                label_map[i] = label if data == 1 else label_map[i]
        label_data = [
            LABELS.index(label) if label != "none" else len(LABELS)
            for label in label_map
        ]
        # Apply one-hot encoding to the dense label representation.
        label_data = keras.utils.to_categorical(label_data, num_classes=len(LABELS) + 1)

        point_clouds.append(point_cloud)
        point_cloud_labels.append(label_data)
        all_labels.append(label_map)
    except KeyError:
        test_point_clouds.append(point_cloud)
# Out:
# 100%|██████████| 4045/4045 [01:35<00:00, 42.46it/s]

# %%
for _ in range(5):
    i = random.randint(0, len(point_clouds) - 1)
    print(f"point_clouds[{i}].shape:", point_clouds[0].shape)
    print(f"point_cloud_labels[{i}].shape:", point_cloud_labels[0].shape)
    for j in range(5):
        print(
            f"all_labels[{i}][{j}]:",
            all_labels[i][j],
            f"\tpoint_cloud_labels[{i}][{j}]:",
            point_cloud_labels[i][j],
            "\n",
        )
# Out:
# point_clouds[669].shape: (2482, 3)
# point_cloud_labels[669].shape: (2482, 5)
# all_labels[669][0]: none 	point_cloud_labels[669][0]: [0. 0. 0. 0. 1.]
#
# all_labels[669][1]: none 	point_cloud_labels[669][1]: [0. 0. 0. 0. 1.]
#
# all_labels[669][2]: none 	point_cloud_labels[669][2]: [0. 0. 0. 0. 1.]
#
# all_labels[669][3]: none 	point_cloud_labels[669][3]: [0. 0. 0. 0. 1.]
#
# all_labels[669][4]: body 	point_cloud_labels[669][4]: [0. 1. 0. 0. 0.]
#
# point_clouds[457].shape: (2482, 3)
# point_cloud_labels[457].shape: (2482, 5)
# all_labels[457][0]: wing 	point_cloud_labels[457][0]: [1. 0. 0. 0. 0.]
#
# all_labels[457][1]: body 	point_cloud_labels[457][1]: [0. 1. 0. 0. 0.]
#
# all_labels[457][2]: wing 	point_cloud_labels[457][2]: [1. 0. 0. 0. 0.]
#
# all_labels[457][3]: wing 	point_cloud_labels[457][3]: [1. 0. 0. 0. 0.]
#
# all_labels[457][4]: body 	point_cloud_labels[457][4]: [0. 1. 0. 0. 0.]
#
# point_clouds[1412].shape: (2482, 3)
# point_cloud_labels[1412].shape: (2482, 5)
# all_labels[1412][0]: body 	point_cloud_labels[1412][0]: [0. 1. 0. 0. 0.]
#
# all_labels[1412][1]: body 	point_cloud_labels[1412][1]: [0. 1. 0. 0. 0.]
#
# all_labels[1412][2]: body 	point_cloud_labels[1412][2]: [0. 1. 0. 0. 0.]
#
# all_labels[1412][3]: tail 	point_cloud_labels[1412][3]: [0. 0. 1. 0. 0.]
#
# all_labels[1412][4]: body 	point_cloud_labels[1412][4]: [0. 1. 0. 0. 0.]
#
# point_clouds[252].shape: (2482, 3)
# point_cloud_labels[252].shape: (2482, 5)
# all_labels[252][0]: body 	point_cloud_labels[252][0]: [0. 1. 0. 0. 0.]
#
# all_labels[252][1]: body 	point_cloud_labels[252][1]: [0. 1. 0. 0. 0.]
#
# all_labels[252][2]: body 	point_cloud_labels[252][2]: [0. 1. 0. 0. 0.]
#
# all_labels[252][3]: body 	point_cloud_labels[252][3]: [0. 1. 0. 0. 0.]
#
# all_labels[252][4]: body 	point_cloud_labels[252][4]: [0. 1. 0. 0. 0.]
#
# point_clouds[2966].shape: (2482, 3)
# point_cloud_labels[2966].shape: (2482, 5)
# all_labels[2966][0]: engine 	point_cloud_labels[2966][0]: [0. 0. 0. 1. 0.]
#
# all_labels[2966][1]: wing 	point_cloud_labels[2966][1]: [1. 0. 0. 0. 0.]
#
# all_labels[2966][2]: wing 	point_cloud_labels[2966][2]: [1. 0. 0. 0. 0.]
#
# all_labels[2966][3]: wing 	point_cloud_labels[2966][3]: [1. 0. 0. 0. 0.]
#
# all_labels[2966][4]: wing 	point_cloud_labels[2966][4]: [1. 0. 0. 0. 0.]

# %%
from mpl_toolkits.mplot3d import Axes3D

def visualize_data(point_cloud, labels):
    unique_labels = np.unique(labels)
    colors = plt.cm.get_cmap("tab10", len(unique_labels))

    df = pd.DataFrame(
        data={
            "x": point_cloud[:, 0],
            "y": point_cloud[:, 1],
            "z": point_cloud[:, 2],
            "label": labels,
        }
    )

    fig = plt.figure(figsize=(15, 10))
    ax = plt.axes(projection="3d")

    for i, label in enumerate(unique_labels):
        c_df = df[df["label"] == label]
        color = colors(i)
        ax.scatter(
            c_df["x"], c_df["y"], c_df["z"], label=label, alpha=0.5, color=color
        )

    ax.legend()
    plt.show()

# Example usage
visualize_data(point_clouds[300], all_labels[300])
# Out:
# <ipython-input-7-f02a056d24c0>:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", len(unique_labels))

# %%
for index in tqdm(range(len(point_clouds))):
    current_point_cloud = point_clouds[index]
    current_label_cloud = point_cloud_labels[index]
    current_labels = all_labels[index]
    num_points = len(current_point_cloud)
    # Randomly sampling respective indices.
    sampled_indices = random.sample(list(range(num_points)), NUM_SAMPLE_POINTS)
    # Sampling points corresponding to sampled indices.
    sampled_point_cloud = np.array([current_point_cloud[i] for i in sampled_indices])
    # Sampling corresponding one-hot encoded labels.
    sampled_label_cloud = np.array([current_label_cloud[i] for i in sampled_indices])
    # Sampling corresponding labels for visualization.
    sampled_labels = np.array([current_labels[i] for i in sampled_indices])
    # Normalizing sampled point cloud.
    norm_point_cloud = sampled_point_cloud - np.mean(sampled_point_cloud, axis=0)
    norm_point_cloud /= np.max(np.linalg.norm(norm_point_cloud, axis=1))
    point_clouds[index] = norm_point_cloud
    point_cloud_labels[index] = sampled_label_cloud
    all_labels[index] = sampled_labels
# Out:
# 100%|██████████| 3686/3686 [00:18<00:00, 200.60it/s]

# %%
visualize_data(point_clouds[300], all_labels[300])
# Out:
# <ipython-input-7-f02a056d24c0>:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", len(unique_labels))

# %%
def load_data(point_cloud_batch, label_cloud_batch):
    point_cloud_batch.set_shape([NUM_SAMPLE_POINTS, 3])
    label_cloud_batch.set_shape([NUM_SAMPLE_POINTS, len(LABELS) + 1])
    return point_cloud_batch, label_cloud_batch


def augment(point_cloud_batch, label_cloud_batch):
    noise = tf.random.uniform(
        tf.shape(label_cloud_batch), -0.001, 0.001, dtype=tf.float64
    )
    point_cloud_batch += noise[:, :, :3]
    return point_cloud_batch, label_cloud_batch

def generate_dataset(point_clouds, label_clouds, is_training=True):
    dataset = tf.data.Dataset.from_tensor_slices((point_clouds, label_clouds))
    dataset = dataset.shuffle(BATCH_SIZE * 100) if is_training else dataset
    dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch_size=BATCH_SIZE)
    dataset = (
        dataset.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
        if is_training
        else dataset
    )
    return dataset

# %%
split_index = int(len(point_clouds) * (1 - VAL_SPLIT))
train_point_clouds = point_clouds[:split_index]
train_label_cloud = point_cloud_labels[:split_index]
total_training_examples = len(train_point_clouds)

val_point_clouds = point_clouds[split_index:]
val_label_cloud = point_cloud_labels[split_index:]

print("Num train point clouds:", len(train_point_clouds))
print("Num train point cloud labels:", len(train_label_cloud))
print("Num val point clouds:", len(val_point_clouds))
print("Num val point cloud labels:", len(val_label_cloud))

train_dataset = generate_dataset(train_point_clouds, train_label_cloud)
val_dataset = generate_dataset(val_point_clouds, val_label_cloud, is_training=False)

print("Train Dataset:", train_dataset)
print("Validation Dataset:", val_dataset)
# Out:
# Num train point clouds: 2948
# Num train point cloud labels: 2948
# Num val point clouds: 738
# Num val point cloud labels: 738
# Train Dataset: <_ParallelMapDataset element_spec=(TensorSpec(shape=(None, 2048, 3), dtype=tf.float64, name=None), TensorSpec(shape=(None, 2048, 5), dtype=tf.float32, name=None))>
# Validation Dataset: <_BatchDataset element_spec=(TensorSpec(shape=(None, 2048, 3), dtype=tf.float64, name=None), TensorSpec(shape=(None, 2048, 5), dtype=tf.float32, name=None))>

# %%
def conv_block(x, filters, name):
    x = layers.Conv1D(filters, kernel_size=1, padding="valid", name=f"{name}_conv")(x)
    x = layers.BatchNormalization(name=f"{name}_batch_norm")(x)
    return layers.Activation("relu", name=f"{name}_relu")(x)


def mlp_block(x, filters, name):
    x = layers.Dense(filters, name=f"{name}_dense")(x)
    x = layers.BatchNormalization(name=f"{name}_batch_norm")(x)
    return layers.Activation("relu", name=f"{name}_relu")(x)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

class OrthogonalRegularizer(keras.regularizers.Regularizer):

    def __init__(self, num_features, l2reg=0.001):
        self.num_features = num_features
        self.l2reg = l2reg
        self.identity = tf.eye(num_features)

    def __call__(self, x):
        x = tf.reshape(x, (-1, self.num_features, self.num_features))
        xxt = tf.tensordot(x, x, axes=(2, 2))
        xxt = tf.reshape(xxt, (-1, self.num_features, self.num_features))
        return tf.reduce_sum(self.l2reg * tf.square(xxt - self.identity))

    def get_config(self):
        config = super().get_config()
        config.update({"num_features": self.num_features, "l2reg_strength": self.l2reg})
        return config

# %%
def transformation_net(inputs, num_features, name):
    x = conv_block(inputs, filters=64, name=f"{name}_1")
    x = conv_block(x, filters=128, name=f"{name}_2")
    x = conv_block(x, filters=1024, name=f"{name}_3")
    x = layers.GlobalMaxPooling1D()(x)
    x = mlp_block(x, filters=512, name=f"{name}_1_1")
    x = mlp_block(x, filters=256, name=f"{name}_2_1")
    return layers.Dense(
        num_features * num_features,
        kernel_initializer="zeros",
        bias_initializer=keras.initializers.Constant(np.eye(num_features).flatten()),
        activity_regularizer=OrthogonalRegularizer(num_features),
        name=f"{name}_final",
    )(x)

def transformation_block(inputs, num_features, name):
    transformed_features = transformation_net(inputs, num_features, name=name)
    transformed_features = layers.Reshape((num_features, num_features))(
        transformed_features
    )
    return layers.Dot(axes=(2, 1), name=f"{name}_mm")([inputs, transformed_features])

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def get_shape_segmentation_model(num_points, num_classes):
    input_points = keras.Input(shape=(None, 3))

    # PointNet Classification Network.
    transformed_inputs = transformation_block(
        input_points, num_features=3, name="input_transformation_block"
    )
    features_64 = conv_block(transformed_inputs, filters=64, name="features_64")
    features_128_1 = conv_block(features_64, filters=128, name="features_128_1")
    features_128_2 = conv_block(features_128_1, filters=128, name="features_128_2")
    transformed_features = transformation_block(
        features_128_2, num_features=128, name="transformed_features"
    )
    features_512 = conv_block(transformed_features, filters=512, name="features_512")
    features_2048 = conv_block(features_512, filters=2048, name="pre_maxpool_block")
    global_features = layers.MaxPool1D(pool_size=num_points, name="global_features")(
        features_2048
    )
    global_features = tf.tile(global_features, [1, num_points, 1])

        # Segmentation head.
    segmentation_input = layers.Concatenate(name="segmentation_input")(
        [
            features_64,
            features_128_1,
            features_128_2,
            transformed_features,
            features_512,
            global_features,
        ]
    )
    segmentation_features = conv_block(
        segmentation_input, filters=128, name="segmentation_features"
    )
    outputs = layers.Conv1D(
        num_classes, kernel_size=1, activation="softmax", name="segmentation_head"
    )(segmentation_features)
    return keras.Model(input_points, outputs)

# %%
x, y = next(iter(train_dataset))

num_points = x.shape[1]
num_classes = y.shape[-1]

segmentation_model = get_shape_segmentation_model(num_points, num_classes)
segmentation_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 3)]            0         []
#
#  input_transformation_block  (None, None, 64)             256       ['input_1[0][0]']
#  _1_conv (Conv1D)
#
#  input_transformation_block  (None, None, 64)             256       ['input_transformation_block_1
#  _1_batch_norm (BatchNormal                                         _conv[0][0]']
#  ization)
#
#  input_transformation_block  (None, None, 64)             0         ['input_transformation_block_1
#  _1_relu (Activation)                                               _batch_norm[0][0]']
#
#  input_transformation_block  (None, None, 128)            8320      ['input_transformation_block_1
#  _2_conv (Conv1D)                                                   _relu[0][0]']
#
#  input_transformation_block  (None, None, 128)            512       ['input_transformation_block_2
#  _2_batch_norm (BatchNormal                                         _conv[0][0]']
#  ization)
#
#  input_transformation_block  (None, None, 128)            0         ['input_transformation_block_2
#  _2_relu (Activation)                                               _batch_norm[0][0]']
#
#  input_transformation_block  (None, None, 1024)           132096    ['input_transformation_block_2
#  _3_conv (Conv1D)                                                   _relu[0][0]']
#
#  input_transformation_block  (None, None, 1024)           4096      ['input_transformation_block_3
#  _3_batch_norm (BatchNormal                                         _conv[0][0]']
#  ization)
#
#  input_transformation_block  (None, None, 1024)           0         ['input_transformation_block_3
#  _3_relu (Activation)                                               _batch_norm[0][0]']
#
#  global_max_pooling1d (Glob  (None, 1024)                 0         ['input_transformation_block_3
#  alMaxPooling1D)                                                    _relu[0][0]']
#
#  input_transformation_block  (None, 512)                  524800    ['global_max_pooling1d[0][0]']
#  _1_1_dense (Dense)
#
#  input_transformation_block  (None, 512)                  2048      ['input_transformation_block_1
#  _1_1_batch_norm (BatchNorm                                         _1_dense[0][0]']
#  alization)
#
#  input_transformation_block  (None, 512)                  0         ['input_transformation_block_1
#  _1_1_relu (Activation)                                             _1_batch_norm[0][0]']
#
#  input_transformation_block  (None, 256)                  131328    ['input_transformation_block_1
#  _2_1_dense (Dense)                                                 _1_relu[0][0]']
#
#  input_transformation_block  (None, 256)                  1024      ['input_transformation_block_2
#  _2_1_batch_norm (BatchNorm                                         _1_dense[0][0]']
#  alization)
#
#  input_transformation_block  (None, 256)                  0         ['input_transformation_block_2
#  _2_1_relu (Activation)                                             _1_batch_norm[0][0]']
#
#  input_transformation_block  (None, 9)                    2313      ['input_transformation_block_2
#  _final (Dense)                                                     _1_relu[0][0]']
#
#  reshape (Reshape)           (None, 3, 3)                 0         ['input_transformation_block_f
#                                                                     inal[0][0]']
#
#  input_transformation_block  (None, None, 3)              0         ['input_1[0][0]',
#  _mm (Dot)                                                           'reshape[0][0]']
#
#  features_64_conv (Conv1D)   (None, None, 64)             256       ['input_transformation_block_m
#                                                                     m[0][0]']
#
#  features_64_batch_norm (Ba  (None, None, 64)             256       ['features_64_conv[0][0]']
#  tchNormalization)
#
#  features_64_relu (Activati  (None, None, 64)             0         ['features_64_batch_norm[0][0]
#  on)                                                                ']
#
#  features_128_1_conv (Conv1  (None, None, 128)            8320      ['features_64_relu[0][0]']
#  D)
#
#  features_128_1_batch_norm   (None, None, 128)            512       ['features_128_1_conv[0][0]']
#  (BatchNormalization)
#
#  features_128_1_relu (Activ  (None, None, 128)            0         ['features_128_1_batch_norm[0]
#  ation)                                                             [0]']
#
#  features_128_2_conv (Conv1  (None, None, 128)            16512     ['features_128_1_relu[0][0]']
#  D)
#
#  features_128_2_batch_norm   (None, None, 128)            512       ['features_128_2_conv[0][0]']
#  (BatchNormalization)
#
#  features_128_2_relu (Activ  (None, None, 128)            0         ['features_128_2_batch_norm[0]
#  ation)                                                             [0]']
#
#  transformed_features_1_con  (None, None, 64)             8256      ['features_128_2_relu[0][0]']
#  v (Conv1D)
#
#  transformed_features_1_bat  (None, None, 64)             256       ['transformed_features_1_conv[
#  ch_norm (BatchNormalizatio                                         0][0]']
#  n)
#
#  transformed_features_1_rel  (None, None, 64)             0         ['transformed_features_1_batch
#  u (Activation)                                                     _norm[0][0]']
#
#  transformed_features_2_con  (None, None, 128)            8320      ['transformed_features_1_relu[
#  v (Conv1D)                                                         0][0]']
#
#  transformed_features_2_bat  (None, None, 128)            512       ['transformed_features_2_conv[
#  ch_norm (BatchNormalizatio                                         0][0]']
#  n)
#
#  transformed_features_2_rel  (None, None, 128)            0         ['transformed_features_2_batch
#  u (Activation)                                                     _norm[0][0]']
#
#  transformed_features_3_con  (None, None, 1024)           132096    ['transformed_features_2_relu[
#  v (Conv1D)                                                         0][0]']
#
#  transformed_features_3_bat  (None, None, 1024)           4096      ['transformed_features_3_conv[
#  ch_norm (BatchNormalizatio                                         0][0]']
#  n)
#
#  transformed_features_3_rel  (None, None, 1024)           0         ['transformed_features_3_batch
#  u (Activation)                                                     _norm[0][0]']
#
#  global_max_pooling1d_1 (Gl  (None, 1024)                 0         ['transformed_features_3_relu[
#  obalMaxPooling1D)                                                  0][0]']
#
#  transformed_features_1_1_d  (None, 512)                  524800    ['global_max_pooling1d_1[0][0]
#  ense (Dense)                                                       ']
#
#  transformed_features_1_1_b  (None, 512)                  2048      ['transformed_features_1_1_den
#  atch_norm (BatchNormalizat                                         se[0][0]']
#  ion)
#
#  transformed_features_1_1_r  (None, 512)                  0         ['transformed_features_1_1_bat
#  elu (Activation)                                                   ch_norm[0][0]']
#
#  transformed_features_2_1_d  (None, 256)                  131328    ['transformed_features_1_1_rel
#  ense (Dense)                                                       u[0][0]']
#
#  transformed_features_2_1_b  (None, 256)                  1024      ['transformed_features_2_1_den
#  atch_norm (BatchNormalizat                                         se[0][0]']
#  ion)
#
#  transformed_features_2_1_r  (None, 256)                  0         ['transformed_features_2_1_bat
#  elu (Activation)                                                   ch_norm[0][0]']
#
#  transformed_features_final  (None, 16384)                4210688   ['transformed_features_2_1_rel
#   (Dense)                                                           u[0][0]']
#
#  reshape_1 (Reshape)         (None, 128, 128)             0         ['transformed_features_final[0
#                                                                     ][0]']
#
#  transformed_features_mm (D  (None, None, 128)            0         ['features_128_2_relu[0][0]',
#  ot)                                                                 'reshape_1[0][0]']
#
#  features_512_conv (Conv1D)  (None, None, 512)            66048     ['transformed_features_mm[0][0
#                                                                     ]']
#
#  features_512_batch_norm (B  (None, None, 512)            2048      ['features_512_conv[0][0]']
#  atchNormalization)
#
#  features_512_relu (Activat  (None, None, 512)            0         ['features_512_batch_norm[0][0
#  ion)                                                               ]']
#
#  pre_maxpool_block_conv (Co  (None, None, 2048)           1050624   ['features_512_relu[0][0]']
#  nv1D)
#
#  pre_maxpool_block_batch_no  (None, None, 2048)           8192      ['pre_maxpool_block_conv[0][0]
#  rm (BatchNormalization)                                            ']
#
#  pre_maxpool_block_relu (Ac  (None, None, 2048)           0         ['pre_maxpool_block_batch_norm
#  tivation)                                                          [0][0]']
#
#  global_features (MaxPoolin  (None, None, 2048)           0         ['pre_maxpool_block_relu[0][0]
#  g1D)                                                               ']
#
#  tf.tile (TFOpLambda)        (None, None, 2048)           0         ['global_features[0][0]']
#
#  segmentation_input (Concat  (None, None, 3008)           0         ['features_64_relu[0][0]',
#  enate)                                                              'features_128_1_relu[0][0]',
#                                                                      'features_128_2_relu[0][0]',
#                                                                      'transformed_features_mm[0][0
#                                                                     ]',
#                                                                      'features_512_relu[0][0]',
#                                                                      'tf.tile[0][0]']
#
#  segmentation_features_conv  (None, None, 128)            385152    ['segmentation_input[0][0]']
#   (Conv1D)
#
#  segmentation_features_batc  (None, None, 128)            512       ['segmentation_features_conv[0
#  h_norm (BatchNormalization                                         ][0]']
#  )
#
#  segmentation_features_relu  (None, None, 128)            0         ['segmentation_features_batch_
#   (Activation)                                                      norm[0][0]']
#
#  segmentation_head (Conv1D)  (None, None, 5)              645       ['segmentation_features_relu[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 7370062 (28.11 MB)
# Trainable params: 7356110 (28.06 MB)
# Non-trainable params: 13952 (54.50 KB)
# __________________________________________________________________________________________________

# %%
EPOCHS = 30
INITIAL_LR = 1e-3
steps_per_epoch = total_training_examples // BATCH_SIZE
total_training_steps = steps_per_epoch * EPOCHS
print(f"Steps per epoch: {steps_per_epoch}.")
print(f"Total training steps: {total_training_steps}.")

lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.003,
    decay_steps=steps_per_epoch * 5,
    decay_rate=0.5,
    staircase=True,
)

steps = range(total_training_steps)
lrs = [lr_schedule(step) for step in steps]

plt.plot(lrs)
plt.xlabel("Steps")
plt.ylabel("Learning Rate")
plt.show()
# Out:
# Steps per epoch: 92.
# Total training steps: 2760.

# %%
def run_experiment(epochs):
    segmentation_model = get_shape_segmentation_model(num_points, num_classes)
    segmentation_model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
        loss=keras.losses.CategoricalCrossentropy(),
        metrics=["accuracy"],
    )

    checkpoint_filepath = "checkpoint.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_loss",
        save_best_only=True,
        save_weights_only=True,
    )

    early_stopping_callback = keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=5,
        restore_best_weights=True,
    )

    history = segmentation_model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=epochs,
        callbacks=[checkpoint_callback, early_stopping_callback],
    )

    segmentation_model.load_weights(checkpoint_filepath)
    return segmentation_model, history

segmentation_model, history = run_experiment(epochs=EPOCHS)
# Out:
# Epoch 1/30
# 93/93 [==============================] - 92s 744ms/step - loss: 32.5209 - accuracy: 0.6648 - val_loss: 1752.5934 - val_accuracy: 0.4964
# Epoch 2/30
# 93/93 [==============================] - 69s 739ms/step - loss: 5.1171 - accuracy: 0.7558 - val_loss: 448.6769 - val_accuracy: 0.6102
# Epoch 3/30
# 93/93 [==============================] - 69s 746ms/step - loss: 4.8576 - accuracy: 0.7845 - val_loss: 138.9134 - val_accuracy: 0.5961
# Epoch 4/30
# 93/93 [==============================] - 69s 744ms/step - loss: 4.7705 - accuracy: 0.7963 - val_loss: 28.8440 - val_accuracy: 0.5700
# Epoch 5/30
# 93/93 [==============================] - 70s 748ms/step - loss: 4.7067 - accuracy: 0.8059 - val_loss: 8.5021 - val_accuracy: 0.5394
# Epoch 6/30
# 93/93 [==============================] - 70s 747ms/step - loss: 4.6708 - accuracy: 0.8160 - val_loss: 5.3749 - val_accuracy: 0.7303
# Epoch 7/30
# 93/93 [==============================] - 70s 748ms/step - loss: 4.6374 - accuracy: 0.8242 - val_loss: 4.8542 - val_accuracy: 0.7714
# Epoch 8/30
# 93/93 [==============================] - 69s 747ms/step - loss: 4.6286 - accuracy: 0.8278 - val_loss: 4.7800 - val_accuracy: 0.7793
# Epoch 9/30
# 93/93 [==============================] - 69s 744ms/step - loss: 4.6143 - accuracy: 0.8309 - val_loss: 4.6627 - val_accuracy: 0.8095
# Epoch 10/30
# 93/93 [==============================] - 69s 745ms/step - loss: 4.5955 - accuracy: 0.8366 - val_loss: 4.6669 - val_accuracy: 0.7929
# Epoch 11/30
# 93/93 [==============================] - 70s 756ms/step - loss: 4.5720 - accuracy: 0.8432 - val_loss: 4.6154 - val_accuracy: 0.8305
# Epoch 12/30
# 93/93 [==============================] - 69s 745ms/step - loss: 4.5608 - accuracy: 0.8463 - val_loss: 4.6242 - val_accuracy: 0.8253
# Epoch 13/30
# 93/93 [==============================] - 70s 752ms/step - loss: 4.5953 - accuracy: 0.8381 - val_loss: 4.6277 - val_accuracy: 0.8207
# Epoch 14/30
# 93/93 [==============================] - 70s 748ms/step - loss: 4.5690 - accuracy: 0.8455 - val_loss: 4.5943 - val_accuracy: 0.8310
# Epoch 15/30
# 93/93 [==============================] - 70s 748ms/step - loss: 4.5541 - accuracy: 0.8481 - val_loss: 4.5633 - val_accuracy: 0.8447
# Epoch 16/30
# 93/93 [==============================] - 69s 746ms/step - loss: 4.5341 - accuracy: 0.8532 - val_loss: 4.5524 - val_accuracy: 0.8455
# Epoch 17/30
# 93/93 [==============================] - 69s 745ms/step - loss: 4.5347 - accuracy: 0.8530 - val_loss: 4.5508 - val_accuracy: 0.8429
# Epoch 18/30
# 93/93 [==============================] - 69s 746ms/step - loss: 4.5315 - accuracy: 0.8534 - val_loss: 4.5689 - val_accuracy: 0.8422
# Epoch 19/30
# 93/93 [==============================] - 69s 744ms/step - loss: 4.5678 - accuracy: 0.8469 - val_loss: 4.5752 - val_accuracy: 0.8380
# Epoch 20/30
# 93/93 [==============================] - 70s 749ms/step - loss: 4.5404 - accuracy: 0.8533 - val_loss: 4.5645 - val_accuracy: 0.8364
# Epoch 21/30
# 93/93 [==============================] - 70s 749ms/step - loss: 4.5208 - accuracy: 0.8583 - val_loss: 4.5476 - val_accuracy: 0.8489
# Epoch 22/30
# 93/93 [==============================] - 70s 747ms/step - loss: 4.5226 - accuracy: 0.8580 - val_loss: 4.5322 - val_accuracy: 0.8535
# Epoch 23/30
# 93/93 [==============================] - 69s 747ms/step - loss: 4.5129 - accuracy: 0.8594 - val_loss: 4.5288 - val_accuracy: 0.8536
# Epoch 24/30
# 93/93 [==============================] - 69s 745ms/step - loss: 4.5129 - accuracy: 0.8603 - val_loss: 4.5347 - val_accuracy: 0.8477
# Epoch 25/30
# 93/93 [==============================] - 69s 745ms/step - loss: 4.5080 - accuracy: 0.8610 - val_loss: 4.5170 - val_accuracy: 0.8554
# Epoch 26/30
# 93/93 [==============================] - 69s 746ms/step - loss: 4.4987 - accuracy: 0.8636 - val_loss: 4.5182 - val_accuracy: 0.8530
# Epoch 27/30
# 93/93 [==============================] - 69s 747ms/step - loss: 4.4986 - accuracy: 0.8637 - val_loss: 4.5145 - val_accuracy: 0.8541
# Epoch 28/30
# 93/93 [==============================] - 69s 745ms/step - loss: 4.4973 - accuracy: 0.8640 - val_loss: 4.5183 - val_accuracy: 0.8528
# Epoch 29/30
# 93/93 [==============================] - 69s 746ms/step - loss: 4.4923 - accuracy: 0.8653 - val_loss: 4.5191 - val_accuracy: 0.8552
# Epoch 30/30
# 93/93 [==============================] - 70s 748ms/step - loss: 4.4959 - accuracy: 0.8643 - val_loss: 4.5105 - val_accuracy: 0.8564

# %%
def plot_result(item):
    plt.plot(history.history[item], label=item)
    plt.plot(history.history["val_" + item], label="val_" + item)
    plt.xlabel("Epochs")
    plt.ylabel(item)
    plt.title("Train and Validation {} Over Epochs".format(item), fontsize=14)
    plt.legend()
    plt.grid()
    plt.show()


plot_result("loss")
plot_result("accuracy")

# %%
def visualizeData(point_cloud, labels):
    df = pd.DataFrame(
        data={
            "x": point_cloud[:, 0],
            "y": point_cloud[:, 1],
            "z": point_cloud[:, 2],
            "label": labels,
        }
    )
    fig = plt.figure(figsize=(15, 10))
    ax = plt.axes(projection="3d")
    for index, label in enumerate(LABELS):
        c_df = df[df["label"] == label]
        try:
            ax.scatter(
                c_df["x"], c_df["y"], c_df["z"], label=label, alpha=0.5, c=COLORS[index]
            )
        except IndexError:
            pass
    ax.legend()
    plt.show()

# %%
validation_batch = next(iter(val_dataset))
val_predictions = segmentation_model.predict(validation_batch[0])
print(f"Validation prediction shape: {val_predictions.shape}")


def visualize_single_point_cloud(point_clouds, label_clouds, idx):
    label_map = LABELS + ["none"]
    point_cloud = point_clouds[idx]
    label_cloud = label_clouds[idx]
    visualize_data(point_cloud, [label_map[np.argmax(label)] for label in label_cloud])


idx = np.random.choice(len(validation_batch[0]))
print(f"Index selected: {idx}")

# Plotting with ground-truth.
visualize_single_point_cloud(validation_batch[0], validation_batch[1], idx)

# Plotting with predicted labels.
visualize_single_point_cloud(validation_batch[0], val_predictions, idx)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# Validation prediction shape: (32, 2048, 5)
# Index selected: 9
# <ipython-input-7-f02a056d24c0>:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", len(unique_labels))
# <ipython-input-7-f02a056d24c0>:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", len(unique_labels))

# %%
def get_shape_classification_model(num_points, num_classes):
    input_points = keras.Input(shape=(None, 3))

    transformed_inputs = transformation_block(
    input_points, num_features=3, name="input_transformation_block")
    features_64 = conv_block(transformed_inputs, filters=64, name="features_64")
    features_128_1 = conv_block(features_64, filters=128, name="features_128_1")
    features_128_2 = conv_block(features_128_1, filters=128, name="features_128_2")
    transformed_features = transformation_block( features_128_2, num_features=128, name="transformed_features")
    features_512 = conv_block(transformed_features, filters=512, name="features_512")
    features_2048 = conv_block(features_512, filters=2048, name="pre_maxpool_block")
    global_features = layers.MaxPool1D(pool_size=num_points, name="global_features")(
        features_2048
    )
    global_features = tf.tile(global_features, [1, num_points, 1])

    # Classification head.
    classification_input = layers.Concatenate(name="classification_input")(
        [
            features_64,
            features_128_1,
            features_128_2,
            transformed_features,
            features_512,
            global_features,
        ]
    )
    classification_features = conv_block(
        classification_input, filters=128, name="classification_features"
    )
    outputs = layers.Dense(
        num_classes, activation="softmax", name="classification_head"
    )(classification_features)
    return keras.Model(input_points, outputs)

# %%
# Instantiate the classification model
classification_model = get_shape_classification_model(num_points, num_classes)
classification_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, None, 3)]            0         []
#
#  input_transformation_block  (None, None, 64)             256       ['input_3[0][0]']
#  _1_conv (Conv1D)
#
#  input_transformation_block  (None, None, 64)             256       ['input_transformation_block_1
#  _1_batch_norm (BatchNormal                                         _conv[0][0]']
#  ization)
#
#  input_transformation_block  (None, None, 64)             0         ['input_transformation_block_1
#  _1_relu (Activation)                                               _batch_norm[0][0]']
#
#  input_transformation_block  (None, None, 128)            8320      ['input_transformation_block_1
#  _2_conv (Conv1D)                                                   _relu[0][0]']
#
#  input_transformation_block  (None, None, 128)            512       ['input_transformation_block_2
#  _2_batch_norm (BatchNormal                                         _conv[0][0]']
#  ization)
#
#  input_transformation_block  (None, None, 128)            0         ['input_transformation_block_2
#  _2_relu (Activation)                                               _batch_norm[0][0]']
#
#  input_transformation_block  (None, None, 1024)           132096    ['input_transformation_block_2
#  _3_conv (Conv1D)                                                   _relu[0][0]']
#
#  input_transformation_block  (None, None, 1024)           4096      ['input_transformation_block_3
#  _3_batch_norm (BatchNormal                                         _conv[0][0]']
#  ization)
#
#  input_transformation_block  (None, None, 1024)           0         ['input_transformation_block_3
#  _3_relu (Activation)                                               _batch_norm[0][0]']
#
#  global_max_pooling1d_4 (Gl  (None, 1024)                 0         ['input_transformation_block_3
#  obalMaxPooling1D)                                                  _relu[0][0]']
#
#  input_transformation_block  (None, 512)                  524800    ['global_max_pooling1d_4[0][0]
#  _1_1_dense (Dense)                                                 ']
#
#  input_transformation_block  (None, 512)                  2048      ['input_transformation_block_1
#  _1_1_batch_norm (BatchNorm                                         _1_dense[0][0]']
#  alization)
#
#  input_transformation_block  (None, 512)                  0         ['input_transformation_block_1
#  _1_1_relu (Activation)                                             _1_batch_norm[0][0]']
#
#  input_transformation_block  (None, 256)                  131328    ['input_transformation_block_1
#  _2_1_dense (Dense)                                                 _1_relu[0][0]']
#
#  input_transformation_block  (None, 256)                  1024      ['input_transformation_block_2
#  _2_1_batch_norm (BatchNorm                                         _1_dense[0][0]']
#  alization)
#
#  input_transformation_block  (None, 256)                  0         ['input_transformation_block_2
#  _2_1_relu (Activation)                                             _1_batch_norm[0][0]']
#
#  input_transformation_block  (None, 9)                    2313      ['input_transformation_block_2
#  _final (Dense)                                                     _1_relu[0][0]']
#
#  reshape_4 (Reshape)         (None, 3, 3)                 0         ['input_transformation_block_f
#                                                                     inal[0][0]']
#
#  input_transformation_block  (None, None, 3)              0         ['input_3[0][0]',
#  _mm (Dot)                                                           'reshape_4[0][0]']
#
#  features_64_conv (Conv1D)   (None, None, 64)             256       ['input_transformation_block_m
#                                                                     m[0][0]']
#
#  features_64_batch_norm (Ba  (None, None, 64)             256       ['features_64_conv[0][0]']
#  tchNormalization)
#
#  features_64_relu (Activati  (None, None, 64)             0         ['features_64_batch_norm[0][0]
#  on)                                                                ']
#
#  features_128_1_conv (Conv1  (None, None, 128)            8320      ['features_64_relu[0][0]']
#  D)
#
#  features_128_1_batch_norm   (None, None, 128)            512       ['features_128_1_conv[0][0]']
#  (BatchNormalization)
#
#  features_128_1_relu (Activ  (None, None, 128)            0         ['features_128_1_batch_norm[0]
#  ation)                                                             [0]']
#
#  features_128_2_conv (Conv1  (None, None, 128)            16512     ['features_128_1_relu[0][0]']
#  D)
#
#  features_128_2_batch_norm   (None, None, 128)            512       ['features_128_2_conv[0][0]']
#  (BatchNormalization)
#
#  features_128_2_relu (Activ  (None, None, 128)            0         ['features_128_2_batch_norm[0]
#  ation)                                                             [0]']
#
#  transformed_features_1_con  (None, None, 64)             8256      ['features_128_2_relu[0][0]']
#  v (Conv1D)
#
#  transformed_features_1_bat  (None, None, 64)             256       ['transformed_features_1_conv[
#  ch_norm (BatchNormalizatio                                         0][0]']
#  n)
#
#  transformed_features_1_rel  (None, None, 64)             0         ['transformed_features_1_batch
#  u (Activation)                                                     _norm[0][0]']
#
#  transformed_features_2_con  (None, None, 128)            8320      ['transformed_features_1_relu[
#  v (Conv1D)                                                         0][0]']
#
#  transformed_features_2_bat  (None, None, 128)            512       ['transformed_features_2_conv[
#  ch_norm (BatchNormalizatio                                         0][0]']
#  n)
#
#  transformed_features_2_rel  (None, None, 128)            0         ['transformed_features_2_batch
#  u (Activation)                                                     _norm[0][0]']
#
#  transformed_features_3_con  (None, None, 1024)           132096    ['transformed_features_2_relu[
#  v (Conv1D)                                                         0][0]']
#
#  transformed_features_3_bat  (None, None, 1024)           4096      ['transformed_features_3_conv[
#  ch_norm (BatchNormalizatio                                         0][0]']
#  n)
#
#  transformed_features_3_rel  (None, None, 1024)           0         ['transformed_features_3_batch
#  u (Activation)                                                     _norm[0][0]']
#
#  global_max_pooling1d_5 (Gl  (None, 1024)                 0         ['transformed_features_3_relu[
#  obalMaxPooling1D)                                                  0][0]']
#
#  transformed_features_1_1_d  (None, 512)                  524800    ['global_max_pooling1d_5[0][0]
#  ense (Dense)                                                       ']
#
#  transformed_features_1_1_b  (None, 512)                  2048      ['transformed_features_1_1_den
#  atch_norm (BatchNormalizat                                         se[0][0]']
#  ion)
#
#  transformed_features_1_1_r  (None, 512)                  0         ['transformed_features_1_1_bat
#  elu (Activation)                                                   ch_norm[0][0]']
#
#  transformed_features_2_1_d  (None, 256)                  131328    ['transformed_features_1_1_rel
#  ense (Dense)                                                       u[0][0]']
#
#  transformed_features_2_1_b  (None, 256)                  1024      ['transformed_features_2_1_den
#  atch_norm (BatchNormalizat                                         se[0][0]']
#  ion)
#
#  transformed_features_2_1_r  (None, 256)                  0         ['transformed_features_2_1_bat
#  elu (Activation)                                                   ch_norm[0][0]']
#
#  transformed_features_final  (None, 16384)                4210688   ['transformed_features_2_1_rel
#   (Dense)                                                           u[0][0]']
#
#  reshape_5 (Reshape)         (None, 128, 128)             0         ['transformed_features_final[0
#                                                                     ][0]']
#
#  transformed_features_mm (D  (None, None, 128)            0         ['features_128_2_relu[0][0]',
#  ot)                                                                 'reshape_5[0][0]']
#
#  features_512_conv (Conv1D)  (None, None, 512)            66048     ['transformed_features_mm[0][0
#                                                                     ]']
#
#  features_512_batch_norm (B  (None, None, 512)            2048      ['features_512_conv[0][0]']
#  atchNormalization)
#
#  features_512_relu (Activat  (None, None, 512)            0         ['features_512_batch_norm[0][0
#  ion)                                                               ]']
#
#  pre_maxpool_block_conv (Co  (None, None, 2048)           1050624   ['features_512_relu[0][0]']
#  nv1D)
#
#  pre_maxpool_block_batch_no  (None, None, 2048)           8192      ['pre_maxpool_block_conv[0][0]
#  rm (BatchNormalization)                                            ']
#
#  pre_maxpool_block_relu (Ac  (None, None, 2048)           0         ['pre_maxpool_block_batch_norm
#  tivation)                                                          [0][0]']
#
#  global_features (MaxPoolin  (None, None, 2048)           0         ['pre_maxpool_block_relu[0][0]
#  g1D)                                                               ']
#
#  tf.tile_2 (TFOpLambda)      (None, None, 2048)           0         ['global_features[0][0]']
#
#  classification_input (Conc  (None, None, 3008)           0         ['features_64_relu[0][0]',
#  atenate)                                                            'features_128_1_relu[0][0]',
#                                                                      'features_128_2_relu[0][0]',
#                                                                      'transformed_features_mm[0][0
#                                                                     ]',
#                                                                      'features_512_relu[0][0]',
#                                                                      'tf.tile_2[0][0]']
#
#  classification_features_co  (None, None, 128)            385152    ['classification_input[0][0]']
#  nv (Conv1D)
#
#  classification_features_ba  (None, None, 128)            512       ['classification_features_conv
#  tch_norm (BatchNormalizati                                         [0][0]']
#  on)
#
#  classification_features_re  (None, None, 128)            0         ['classification_features_batc
#  lu (Activation)                                                    h_norm[0][0]']
#
#  classification_head (Dense  (None, None, 5)              645       ['classification_features_relu
#  )                                                                  [0][0]']
#
# ==================================================================================================
# Total params: 7370062 (28.11 MB)
# Trainable params: 7356110 (28.06 MB)
# Non-trainable params: 13952 (54.50 KB)
# __________________________________________________________________________________________________

# %%
def run_classification_experiment(epochs):
    classification_model = get_shape_classification_model(num_points, num_classes)
    classification_model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
        loss=keras.losses.CategoricalCrossentropy(),
        metrics=["accuracy"],
    )

    checkpoint_filepath = "classification_checkpoint.weights.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_loss",
        save_best_only=True,
        save_weights_only=True,
    )

    classification_history = classification_model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=epochs,
        callbacks=[checkpoint_callback],
    )

    classification_model.load_weights(checkpoint_filepath)
    return classification_model, classification_history


classification_model, classification_history = run_classification_experiment(
    epochs=EPOCHS
)
# Out:
# Epoch 1/30
# 93/93 [==============================] - 81s 756ms/step - loss: 21.7267 - accuracy: 0.7123 - val_loss: 131.1087 - val_accuracy: 0.4811
# Epoch 2/30
# 93/93 [==============================] - 71s 759ms/step - loss: 4.9122 - accuracy: 0.7815 - val_loss: 29.2108 - val_accuracy: 0.4463
# Epoch 3/30
# 93/93 [==============================] - 70s 749ms/step - loss: 4.8696 - accuracy: 0.7915 - val_loss: 8.7770 - val_accuracy: 0.5199
# Epoch 4/30
# 93/93 [==============================] - 69s 746ms/step - loss: 4.7442 - accuracy: 0.8051 - val_loss: 5.6601 - val_accuracy: 0.6297
# Epoch 5/30
# 93/93 [==============================] - 70s 756ms/step - loss: 4.6852 - accuracy: 0.8173 - val_loss: 5.8140 - val_accuracy: 0.6938
# Epoch 6/30
# 93/93 [==============================] - 70s 750ms/step - loss: 5.1176 - accuracy: 0.7916 - val_loss: 5.3515 - val_accuracy: 0.7324
# Epoch 7/30
# 93/93 [==============================] - 70s 748ms/step - loss: 4.6934 - accuracy: 0.8113 - val_loss: 4.8321 - val_accuracy: 0.7732
# Epoch 8/30
# 93/93 [==============================] - 69s 746ms/step - loss: 4.6560 - accuracy: 0.8202 - val_loss: 4.7053 - val_accuracy: 0.7945
# Epoch 9/30
# 93/93 [==============================] - 70s 749ms/step - loss: 4.6146 - accuracy: 0.8310 - val_loss: 4.6469 - val_accuracy: 0.8093
# Epoch 10/30
# 93/93 [==============================] - 70s 750ms/step - loss: 4.6041 - accuracy: 0.8328 - val_loss: 4.5905 - val_accuracy: 0.8298
# Epoch 11/30
# 93/93 [==============================] - 69s 744ms/step - loss: 4.5814 - accuracy: 0.8415 - val_loss: 4.6727 - val_accuracy: 0.7960
# Epoch 12/30
# 93/93 [==============================] - 69s 743ms/step - loss: 5.0076 - accuracy: 0.7908 - val_loss: 4.7642 - val_accuracy: 0.7890
# Epoch 13/30
# 93/93 [==============================] - 69s 743ms/step - loss: 4.7062 - accuracy: 0.8110 - val_loss: 4.6814 - val_accuracy: 0.8088
# Epoch 14/30
# 93/93 [==============================] - 69s 744ms/step - loss: 4.6434 - accuracy: 0.8207 - val_loss: 4.6422 - val_accuracy: 0.8124
# Epoch 15/30
# 93/93 [==============================] - 69s 746ms/step - loss: 4.6177 - accuracy: 0.8284 - val_loss: 4.6191 - val_accuracy: 0.8159
# Epoch 16/30
# 93/93 [==============================] - 69s 745ms/step - loss: 4.5782 - accuracy: 0.8384 - val_loss: 4.5921 - val_accuracy: 0.8290
# Epoch 17/30
# 93/93 [==============================] - 70s 748ms/step - loss: 4.5744 - accuracy: 0.8389 - val_loss: 4.5747 - val_accuracy: 0.8348
# Epoch 18/30
# 93/93 [==============================] - 69s 746ms/step - loss: 4.5663 - accuracy: 0.8419 - val_loss: 4.6388 - val_accuracy: 0.8172
# Epoch 19/30
# 93/93 [==============================] - 70s 750ms/step - loss: 4.5624 - accuracy: 0.8437 - val_loss: 4.5694 - val_accuracy: 0.8333
# Epoch 20/30
# 93/93 [==============================] - 69s 745ms/step - loss: 4.5510 - accuracy: 0.8473 - val_loss: 4.5713 - val_accuracy: 0.8331
# Epoch 21/30
# 93/93 [==============================] - 70s 755ms/step - loss: 4.5364 - accuracy: 0.8496 - val_loss: 4.5744 - val_accuracy: 0.8279
# Epoch 22/30
# 93/93 [==============================] - 70s 749ms/step - loss: 4.5314 - accuracy: 0.8509 - val_loss: 4.5404 - val_accuracy: 0.8457
# Epoch 23/30
# 93/93 [==============================] - 69s 745ms/step - loss: 4.5273 - accuracy: 0.8522 - val_loss: 4.5422 - val_accuracy: 0.8448
# Epoch 24/30
# 93/93 [==============================] - 69s 745ms/step - loss: 4.5264 - accuracy: 0.8530 - val_loss: 4.5439 - val_accuracy: 0.8442
# Epoch 25/30
# 93/93 [==============================] - 70s 749ms/step - loss: 4.5246 - accuracy: 0.8537 - val_loss: 4.5310 - val_accuracy: 0.8493
# Epoch 26/30
# 93/93 [==============================] - 70s 748ms/step - loss: 4.5101 - accuracy: 0.8575 - val_loss: 4.5267 - val_accuracy: 0.8509
# Epoch 27/30
# 93/93 [==============================] - 69s 745ms/step - loss: 4.5163 - accuracy: 0.8564 - val_loss: 4.5375 - val_accuracy: 0.8441
# Epoch 28/30
# 93/93 [==============================] - 69s 742ms/step - loss: 4.5108 - accuracy: 0.8574 - val_loss: 4.5287 - val_accuracy: 0.8469
# Epoch 29/30
# 93/93 [==============================] - 69s 746ms/step - loss: 4.5115 - accuracy: 0.8577 - val_loss: 4.5285 - val_accuracy: 0.8483
# Epoch 30/30
# 93/93 [==============================] - 69s 747ms/step - loss: 4.5051 - accuracy: 0.8594 - val_loss: 4.5243 - val_accuracy: 0.8498

# %%
def plot_classification_result(item):
    plt.plot(classification_history.history[item], label=item)
    plt.plot(classification_history.history["val_" + item], label="val_" + item)
    plt.xlabel("Epochs")
    plt.ylabel(item)
    plt.title("Train and Validation {} Over Epochs".format(item), fontsize=14)
    plt.legend()
    plt.grid()
    plt.show()

# Visualize training landscape for classification
plot_classification_result("loss")
plot_classification_result("accuracy")

# %%
def visualize_single_point_cloud1(point_clouds, label_clouds, idx, labels):
    label_map = labels + ["none"]
    point_cloud = point_clouds[idx]
    label_cloud = label_clouds[idx]
    visualize_data(point_cloud, [label_map[np.argmax(label)] for label in label_cloud])

# %%
validation_batch_classification = next(iter(val_dataset))
val_predictions_classification = classification_model.predict(validation_batch_classification[0])

# Visualize a single point cloud with ground-truth labels and predicted labels
idx_classification = np.random.choice(len(validation_batch_classification[0]))
print(f"Index selected: {idx_classification}")

# Plotting with ground-truth labels
ground_truth_labels = [LABELS[np.argmax(label)] for label in validation_batch_classification[1][idx_classification]]
visualize_single_point_cloud1(validation_batch_classification[0], validation_batch_classification[1], idx_classification, LABELS)
print(f"Ground Truth Labels: {ground_truth_labels}")

# Plotting with predicted labels
predicted_labels = [LABELS[np.argmax(label)] for label in val_predictions_classification[idx_classification]]
visualize_single_point_cloud1(validation_batch_classification[0], val_predictions_classification, idx_classification, LABELS)
print(f"Predicted Labels: {predicted_labels}")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Index selected: 5
# <ipython-input-7-f02a056d24c0>:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", len(unique_labels))
# Ground Truth Labels: ['body', 'body', 'engine', 'body', 'body', 'wing', 'body', 'body', 'wing', 'wing', 'body', 'tail', 'wing', 'wing', 'wing', 'body', 'body', 'tail', 'body', 'body', 'body', 'body', 'wing', 'tail', 'body', 'tail', 'tail', 'body', 'engine', 'tail', 'body', 'body', 'wing', 'wing', 'body', 'wing', 'body', 'engine', 'tail', 'body', 'body', 'wing', 'engine', 'body', 'body', 'engine', 'body', 'body', 'body', 'body', 'engine', 'body', 'body', 'engine', 'engine', 'wing', 'body', 'wing', 'engine', 'body', 'wing', 'wing', 'wing', 'tail', 'wing', 'wing', 'body', 'body', 'wing', 'wing', 'body', 'engine', 'body', 'body', 'body', 'body', 'wing', 'body', 'engine', 'engine', 'body', 'body', 'body', 'body', 'wing', 'wing', 'body', 'wing', 'wing', 'body', 'wing', 'wing', 'engine', 'body', 'wing', 'wing', 'body', 'engine', 'wing', 'body', 'wing', 'tail', 'body', 'body', 'body', 'body', 'tail', 'tail', 'wing', 'engine', 'body', 'tail', 'wing', 'body', 'body', 'body', 'body', 'wing', 'body', 'body', 'body', 'body', 'tail', 'tail', 'body', 'body', 'wing', 'tail', 'body', 'body', 'wing', 'wing', 'body', 'engine', 'wing', 'body', 'body', 'body', 'wing', 'engine', 'body', 'body', 'body', 'body', 'body', 'wing', 'body', 'wing', 'wing', 'body', 'engine', 'engine', 'body', 'engine', 'wing', 'body', 'body', 'wing', 'engine', 'wing', 'wing', 'body', 'wing', 'body', 'body', 'body', 'tail', 'wing', 'body', 'engine', 'wing', 'wing', 'wing', 'body', 'wing', 'engine', 'body', 'body', 'body', 'wing', 'wing', 'body', 'body', 'body', 'tail', 'body', 'wing', 'body', 'tail', 'body', 'body', 'tail', 'body', 'body', 'tail', 'body', 'engine', 'wing', 'body', 'wing', 'body', 'wing', 'body', 'wing', 'engine', 'body', 'body', 'body', 'wing', 'body', 'wing', 'body', 'body', 'body', 'body', 'body', 'wing', 'body', 'wing', 'body', 'body', 'engine', 'wing', 'wing', 'body', 'body', 'body', 'engine', 'body', 'body', 'body', 'body', 'body', 'body', 'body', 'engine', 'engine', 'body', 'body', 'body', 'wing', 'body', 'engine', 'wing', 'body', 'body', 'body', 'engine', 'body', 'body', 'engine', 'engine', 'wing', 'tail', 'body', 'body', 'wing', 'body', 'engine', 'engine', 'tail', 'body', 'wing', 'body', 'body', 'engine', 'wing', 'wing', 'body', 'wing', 'body', 'body', 'wing', 'wing', 'tail', 'body', 'engine', 'body', 'body', 'body', 'wing', 'body', 'tail', 'body', 'body', 'wing', 'tail', 'tail', 'body', 'engine', 'body', 'body', 'body', 'wing', 'body', 'body', 'wing', 'body', 'body', 'tail', 'tail', 'tail', 'body', 'engine', 'wing', 'wing', 'wing', 'body', 'body', 'wing', 'body', 'body', 'wing', 'wing', 'body', 'body', 'engine', 'wing', 'engine', 'body', 'wing', 'engine', 'wing', 'wing', 'body', 'body', 'body', 'body', 'body', 'body', 'engine', 'body', 'wing', 'wing', 'body', 'body', 'engine', 'engine', 'body', 'tail', 'wing', 'engine', 'body', 'wing', 'engine', 'engine', 'tail', 'wing', 'body', 'tail', 'engine', 'engine', 'engine', 'body', 'tail', 'wing', 'body', 'body', 'body', 'engine', 'engine', 'body', 'body', 'wing', 'wing', 'engine', 'body', 'body', 'tail', 'engine', 'body', 'body', 'body', 'body', 'body', 'wing', 'body', 'body', 'body', 'tail', 'body', 'body', 'tail', 'tail', 'wing', 'wing', 'body', 'body', 'wing', 'wing', 'body', 'engine', 'wing', 'body', 'wing', 'body', 'body', 'body', 'body', 'wing', 'tail', 'body', 'body', 'body', 'engine', 'body', 'engine', 'wing', 'engine', 'body', 'wing', 'tail', 'wing', 'body', 'wing', 'body', 'engine', 'body', 'body', 'engine', 'wing', 'body', 'wing', 'tail', 'engine', 'wing', 'body', 'wing', 'tail', 'body', 'body', 'body', 'body', 'body', 'wing', 'engine', 'body', 'wing', 'engine', 'body', 'body', 'body', 'wing', 'body', 'wing', 'body', 'wing', 'body', 'body', 'wing', 'body', 'tail', 'tail', 'wing', 'engine', 'wing', 'tail', 'body', 'wing', 'wing', 'wing', 'body', 'tail', 'engine', 'wing', 'tail', 'wing', 'body', 'body', 'body', 'wing', 'engine', 'body', 'body', 'body', 'wing', 'body', 'tail', 'wing', 'tail', 'tai ...
# <ipython-input-7-f02a056d24c0>:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", len(unique_labels))
# Predicted Labels: ['tail', 'body', 'engine', 'body', 'body', 'wing', 'body', 'body', 'wing', 'wing', 'body', 'tail', 'wing', 'wing', 'wing', 'body', 'body', 'tail', 'wing', 'body', 'body', 'tail', 'wing', 'tail', 'body', 'tail', 'tail', 'body', 'engine', 'tail', 'body', 'body', 'wing', 'wing', 'body', 'wing', 'body', 'engine', 'tail', 'body', 'body', 'wing', 'engine', 'body', 'body', 'wing', 'wing', 'body', 'body', 'body', 'engine', 'body', 'body', 'engine', 'engine', 'wing', 'body', 'wing', 'engine', 'body', 'wing', 'wing', 'wing', 'tail', 'wing', 'wing', 'body', 'body', 'wing', 'wing', 'body', 'engine', 'body', 'body', 'body', 'body', 'wing', 'body', 'engine', 'engine', 'body', 'body', 'body', 'body', 'wing', 'wing', 'body', 'wing', 'wing', 'body', 'wing', 'wing', 'engine', 'body', 'wing', 'wing', 'body', 'engine', 'wing', 'body', 'wing', 'tail', 'tail', 'tail', 'body', 'body', 'tail', 'tail', 'wing', 'engine', 'body', 'tail', 'wing', 'body', 'body', 'body', 'body', 'wing', 'body', 'body', 'body', 'body', 'tail', 'tail', 'body', 'body', 'wing', 'tail', 'body', 'body', 'wing', 'wing', 'body', 'engine', 'wing', 'body', 'body', 'body', 'wing', 'engine', 'body', 'body', 'body', 'body', 'body', 'wing', 'tail', 'wing', 'wing', 'body', 'engine', 'engine', 'body', 'engine', 'wing', 'body', 'body', 'wing', 'engine', 'wing', 'wing', 'body', 'wing', 'body', 'body', 'body', 'tail', 'wing', 'body', 'engine', 'wing', 'wing', 'wing', 'body', 'wing', 'engine', 'body', 'body', 'body', 'wing', 'wing', 'body', 'body', 'body', 'tail', 'body', 'wing', 'body', 'tail', 'body', 'body', 'tail', 'body', 'body', 'tail', 'wing', 'wing', 'wing', 'body', 'wing', 'body', 'wing', 'body', 'wing', 'engine', 'body', 'body', 'body', 'wing', 'body', 'wing', 'body', 'tail', 'body', 'body', 'body', 'wing', 'body', 'wing', 'body', 'body', 'engine', 'wing', 'wing', 'body', 'body', 'body', 'engine', 'body', 'body', 'body', 'body', 'body', 'body', 'body', 'wing', 'wing', 'body', 'body', 'body', 'wing', 'body', 'wing', 'wing', 'body', 'body', 'body', 'engine', 'body', 'body', 'engine', 'engine', 'wing', 'tail', 'body', 'body', 'wing', 'body', 'engine', 'wing', 'tail', 'body', 'wing', 'body', 'body', 'engine', 'wing', 'wing', 'body', 'wing', 'body', 'body', 'wing', 'wing', 'tail', 'body', 'wing', 'body', 'body', 'body', 'wing', 'body', 'tail', 'body', 'body', 'wing', 'tail', 'tail', 'body', 'engine', 'body', 'body', 'body', 'wing', 'body', 'body', 'wing', 'body', 'body', 'tail', 'tail', 'tail', 'body', 'engine', 'wing', 'wing', 'wing', 'body', 'body', 'wing', 'body', 'body', 'wing', 'wing', 'body', 'body', 'engine', 'wing', 'engine', 'wing', 'wing', 'engine', 'wing', 'wing', 'body', 'body', 'body', 'body', 'body', 'body', 'engine', 'body', 'wing', 'wing', 'body', 'body', 'engine', 'engine', 'body', 'tail', 'wing', 'wing', 'body', 'wing', 'engine', 'engine', 'tail', 'wing', 'wing', 'tail', 'engine', 'engine', 'engine', 'body', 'tail', 'wing', 'body', 'body', 'wing', 'engine', 'engine', 'body', 'body', 'wing', 'wing', 'engine', 'body', 'body', 'tail', 'engine', 'body', 'body', 'body', 'body', 'body', 'wing', 'body', 'body', 'tail', 'tail', 'tail', 'tail', 'tail', 'tail', 'wing', 'wing', 'body', 'body', 'wing', 'wing', 'body', 'engine', 'wing', 'body', 'wing', 'wing', 'body', 'body', 'body', 'wing', 'tail', 'body', 'body', 'body', 'engine', 'body', 'engine', 'wing', 'wing', 'body', 'wing', 'tail', 'wing', 'body', 'wing', 'body', 'engine', 'body', 'wing', 'engine', 'wing', 'body', 'wing', 'tail', 'engine', 'wing', 'body', 'wing', 'tail', 'body', 'body', 'body', 'body', 'body', 'wing', 'engine', 'body', 'wing', 'engine', 'body', 'body', 'wing', 'wing', 'body', 'wing', 'body', 'wing', 'body', 'body', 'wing', 'wing', 'tail', 'tail', 'wing', 'engine', 'wing', 'tail', 'body', 'wing', 'wing', 'wing', 'body', 'tail', 'engine', 'wing', 'tail', 'wing', 'body', 'body', 'body', 'wing', 'engine', 'body', 'body', 'body', 'wing', 'body', 'tail', 'wing', 'tail', 'tail', 'body', 'engine', ...

# %%
num_correct = sum(1 for gt, pred in zip(ground_truth_labels, predicted_labels) if gt == pred)
total_predictions = len(ground_truth_labels)

accuracy = (num_correct / total_predictions) * 100
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# Accuracy: 93.95%

# %%
test_results = classification_model.evaluate(val_dataset)

# Extracting metrics
test_loss = test_results[0]
test_accuracy = test_results[1]

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.2%}")
# Out:
# 24/24 [==============================] - 4s 173ms/step - loss: 4.5243 - accuracy: 0.8498
# Test Loss: 4.5243
# Test Accuracy: 84.98%

# %%
validation_batch_classification = next(iter(val_dataset))
val_predictions_classification = classification_model.predict(validation_batch_classification[0])

# Visualize a single point cloud with ground-truth labels and predicted labels
idx_classification = np.random.choice(len(validation_batch_classification[0]))
print(f"Index selected: {idx_classification}")

# Plotting with ground-truth labels
ground_truth_labels = [LABELS[np.argmax(label)] for label in validation_batch_classification[1][idx_classification]]
visualize_single_point_cloud1(validation_batch_classification[0], validation_batch_classification[1], idx_classification, LABELS)
print(f"Ground Truth Labels: {ground_truth_labels}")

# Plotting with predicted labels
predicted_labels = [LABELS[np.argmax(label)] for label in val_predictions_classification[idx_classification]]
visualize_single_point_cloud1(validation_batch_classification[0], val_predictions_classification, idx_classification, LABELS)
print(f"Predicted Labels: {predicted_labels}")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Index selected: 29
# <ipython-input-7-f02a056d24c0>:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", len(unique_labels))
# Ground Truth Labels: ['body', 'tail', 'body', 'wing', 'body', 'body', 'wing', 'wing', 'engine', 'engine', 'wing', 'body', 'engine', 'body', 'wing', 'body', 'tail', 'wing', 'body', 'wing', 'wing', 'body', 'engine', 'body', 'engine', 'wing', 'wing', 'body', 'body', 'body', 'body', 'engine', 'body', 'body', 'wing', 'body', 'wing', 'body', 'body', 'body', 'body', 'wing', 'body', 'body', 'body', 'body', 'body', 'body', 'wing', 'wing', 'body', 'body', 'engine', 'body', 'body', 'engine', 'wing', 'body', 'body', 'tail', 'wing', 'wing', 'tail', 'body', 'tail', 'wing', 'wing', 'wing', 'wing', 'wing', 'body', 'wing', 'body', 'wing', 'tail', 'body', 'body', 'wing', 'body', 'body', 'body', 'wing', 'wing', 'body', 'wing', 'body', 'wing', 'tail', 'body', 'body', 'body', 'wing', 'tail', 'body', 'engine', 'body', 'body', 'wing', 'body', 'body', 'body', 'body', 'wing', 'body', 'body', 'wing', 'tail', 'wing', 'body', 'tail', 'wing', 'body', 'body', 'body', 'engine', 'wing', 'wing', 'body', 'wing', 'body', 'wing', 'wing', 'body', 'engine', 'body', 'wing', 'body', 'body', 'body', 'tail', 'tail', 'body', 'body', 'wing', 'tail', 'body', 'body', 'body', 'tail', 'body', 'body', 'body', 'tail', 'body', 'body', 'wing', 'wing', 'body', 'body', 'body', 'body', 'tail', 'wing', 'wing', 'body', 'engine', 'wing', 'body', 'body', 'body', 'body', 'body', 'wing', 'wing', 'wing', 'body', 'tail', 'body', 'body', 'body', 'engine', 'engine', 'body', 'body', 'wing', 'body', 'engine', 'wing', 'body', 'wing', 'engine', 'wing', 'wing', 'body', 'body', 'body', 'body', 'body', 'wing', 'tail', 'tail', 'tail', 'engine', 'wing', 'body', 'wing', 'body', 'wing', 'tail', 'wing', 'body', 'body', 'tail', 'body', 'body', 'body', 'wing', 'body', 'body', 'tail', 'body', 'wing', 'wing', 'body', 'wing', 'body', 'body', 'tail', 'body', 'body', 'tail', 'wing', 'tail', 'tail', 'engine', 'body', 'body', 'body', 'body', 'engine', 'body', 'tail', 'wing', 'wing', 'wing', 'body', 'body', 'wing', 'body', 'wing', 'body', 'tail', 'engine', 'wing', 'tail', 'wing', 'wing', 'body', 'body', 'engine', 'wing', 'body', 'tail', 'tail', 'wing', 'body', 'wing', 'body', 'wing', 'body', 'body', 'body', 'engine', 'tail', 'tail', 'wing', 'body', 'wing', 'body', 'body', 'tail', 'tail', 'engine', 'body', 'body', 'body', 'body', 'body', 'body', 'wing', 'wing', 'body', 'body', 'engine', 'body', 'tail', 'body', 'tail', 'engine', 'wing', 'wing', 'engine', 'body', 'tail', 'body', 'body', 'wing', 'tail', 'body', 'tail', 'body', 'body', 'body', 'body', 'wing', 'wing', 'body', 'tail', 'wing', 'body', 'body', 'tail', 'wing', 'body', 'body', 'body', 'wing', 'wing', 'engine', 'wing', 'body', 'body', 'body', 'wing', 'body', 'engine', 'engine', 'tail', 'wing', 'engine', 'body', 'engine', 'wing', 'engine', 'engine', 'body', 'body', 'wing', 'body', 'wing', 'body', 'body', 'engine', 'body', 'tail', 'wing', 'engine', 'body', 'body', 'engine', 'body', 'tail', 'body', 'engine', 'wing', 'wing', 'wing', 'body', 'body', 'body', 'wing', 'engine', 'wing', 'tail', 'engine', 'engine', 'wing', 'wing', 'body', 'wing', 'engine', 'wing', 'wing', 'body', 'tail', 'wing', 'body', 'wing', 'body', 'wing', 'tail', 'engine', 'body', 'wing', 'tail', 'wing', 'wing', 'wing', 'body', 'body', 'tail', 'engine', 'engine', 'tail', 'engine', 'wing', 'wing', 'wing', 'wing', 'body', 'engine', 'tail', 'body', 'body', 'wing', 'wing', 'wing', 'body', 'wing', 'wing', 'body', 'wing', 'tail', 'wing', 'wing', 'tail', 'tail', 'body', 'engine', 'body', 'body', 'wing', 'engine', 'body', 'engine', 'body', 'body', 'body', 'body', 'engine', 'body', 'wing', 'body', 'wing', 'body', 'tail', 'body', 'engine', 'body', 'body', 'tail', 'body', 'tail', 'tail', 'wing', 'wing', 'body', 'body', 'wing', 'wing', 'wing', 'body', 'wing', 'wing', 'wing', 'body', 'body', 'tail', 'tail', 'body', 'engine', 'body', 'body', 'body', 'body', 'body', 'wing', 'body', 'body', 'body', 'wing', 'body', 'body', 'engine', 'engine', 'body', 'wing', 'body', 'tail', 'body', 'tail', 'body', 'wing', 'engin ...
# <ipython-input-7-f02a056d24c0>:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", len(unique_labels))
# Predicted Labels: ['body', 'tail', 'wing', 'wing', 'body', 'body', 'wing', 'wing', 'engine', 'engine', 'wing', 'wing', 'engine', 'body', 'wing', 'body', 'tail', 'wing', 'wing', 'wing', 'wing', 'body', 'body', 'body', 'engine', 'wing', 'wing', 'body', 'body', 'body', 'body', 'engine', 'body', 'body', 'wing', 'body', 'wing', 'wing', 'body', 'body', 'body', 'wing', 'body', 'body', 'body', 'body', 'body', 'body', 'wing', 'wing', 'body', 'body', 'wing', 'body', 'body', 'engine', 'wing', 'body', 'body', 'tail', 'wing', 'wing', 'tail', 'body', 'tail', 'wing', 'wing', 'wing', 'wing', 'wing', 'body', 'wing', 'body', 'wing', 'tail', 'body', 'body', 'wing', 'body', 'body', 'body', 'wing', 'wing', 'body', 'wing', 'body', 'wing', 'tail', 'body', 'body', 'wing', 'wing', 'tail', 'body', 'engine', 'wing', 'body', 'wing', 'body', 'body', 'body', 'body', 'wing', 'body', 'body', 'wing', 'tail', 'wing', 'body', 'tail', 'wing', 'body', 'body', 'body', 'engine', 'wing', 'wing', 'body', 'wing', 'body', 'wing', 'wing', 'body', 'wing', 'body', 'wing', 'body', 'body', 'body', 'tail', 'tail', 'body', 'body', 'wing', 'tail', 'body', 'body', 'body', 'tail', 'body', 'wing', 'body', 'tail', 'body', 'body', 'wing', 'wing', 'body', 'body', 'body', 'body', 'tail', 'wing', 'wing', 'body', 'engine', 'wing', 'body', 'body', 'body', 'body', 'body', 'wing', 'wing', 'wing', 'body', 'tail', 'body', 'body', 'body', 'engine', 'engine', 'body', 'body', 'wing', 'body', 'engine', 'wing', 'body', 'wing', 'engine', 'wing', 'wing', 'body', 'body', 'body', 'body', 'body', 'wing', 'tail', 'tail', 'tail', 'engine', 'engine', 'body', 'wing', 'body', 'wing', 'tail', 'wing', 'body', 'body', 'tail', 'body', 'body', 'body', 'wing', 'body', 'body', 'body', 'body', 'wing', 'wing', 'body', 'wing', 'body', 'body', 'tail', 'body', 'body', 'tail', 'wing', 'tail', 'tail', 'engine', 'wing', 'body', 'body', 'body', 'engine', 'body', 'tail', 'wing', 'wing', 'wing', 'body', 'body', 'wing', 'body', 'engine', 'body', 'tail', 'engine', 'wing', 'tail', 'wing', 'wing', 'body', 'body', 'engine', 'wing', 'body', 'tail', 'tail', 'wing', 'body', 'wing', 'body', 'engine', 'body', 'body', 'body', 'engine', 'tail', 'tail', 'wing', 'body', 'wing', 'body', 'body', 'tail', 'tail', 'engine', 'body', 'body', 'body', 'body', 'body', 'body', 'wing', 'wing', 'body', 'body', 'engine', 'wing', 'tail', 'body', 'tail', 'engine', 'wing', 'wing', 'engine', 'body', 'tail', 'body', 'body', 'wing', 'tail', 'body', 'tail', 'body', 'body', 'body', 'body', 'wing', 'wing', 'body', 'tail', 'wing', 'body', 'body', 'tail', 'wing', 'body', 'body', 'body', 'wing', 'wing', 'engine', 'wing', 'body', 'body', 'body', 'body', 'body', 'engine', 'engine', 'tail', 'wing', 'engine', 'body', 'engine', 'wing', 'engine', 'engine', 'wing', 'body', 'wing', 'body', 'wing', 'wing', 'body', 'engine', 'body', 'tail', 'wing', 'engine', 'body', 'body', 'engine', 'body', 'tail', 'body', 'engine', 'wing', 'wing', 'wing', 'body', 'body', 'body', 'wing', 'engine', 'wing', 'tail', 'engine', 'engine', 'wing', 'wing', 'body', 'wing', 'engine', 'wing', 'wing', 'body', 'tail', 'wing', 'body', 'wing', 'body', 'wing', 'tail', 'engine', 'body', 'wing', 'tail', 'wing', 'wing', 'wing', 'body', 'body', 'tail', 'engine', 'engine', 'tail', 'engine', 'wing', 'wing', 'wing', 'wing', 'body', 'engine', 'tail', 'body', 'body', 'wing', 'wing', 'wing', 'body', 'wing', 'wing', 'body', 'wing', 'tail', 'wing', 'wing', 'tail', 'tail', 'body', 'engine', 'body', 'body', 'wing', 'engine', 'body', 'engine', 'body', 'body', 'body', 'body', 'engine', 'body', 'engine', 'body', 'wing', 'body', 'tail', 'body', 'engine', 'body', 'body', 'tail', 'body', 'tail', 'tail', 'wing', 'body', 'body', 'body', 'wing', 'wing', 'wing', 'body', 'wing', 'wing', 'wing', 'body', 'body', 'tail', 'tail', 'body', 'engine', 'body', 'body', 'body', 'body', 'body', 'wing', 'body', 'body', 'body', 'wing', 'body', 'body', 'engine', 'engine', 'body', 'wing', 'body', 'tail', 'body', 'tail', 'body', 'wing', 'engine ...

# %%
num_correct = sum(1 for gt, pred in zip(ground_truth_labels, predicted_labels) if gt == pred)
total_predictions = len(ground_truth_labels)

accuracy = (num_correct / total_predictions) * 100
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# Accuracy: 95.26%

# %%
test_results = classification_model.evaluate(val_dataset)

# Extracting metrics
test_loss = test_results[0]
test_accuracy = test_results[1]

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.2%}")
# Out:
# 24/24 [==============================] - 4s 176ms/step - loss: 4.5243 - accuracy: 0.8498
# Test Loss: 4.5243
# Test Accuracy: 84.98%
